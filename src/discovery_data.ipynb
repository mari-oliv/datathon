# %%
import pandas as pd

# %%
data = pd.read_excel("data/base_dados_pede_2024.xlsx")
data.head()
# Out:
#      RA  Fase Turma     Nome  Ano nasc  Idade 22  Gênero  Ano ingresso  \
# 0  RA-1     7     A  Aluno-1      2003        19  Menina          2016
# 1  RA-2     7     A  Aluno-2      2005        17  Menina          2017
# 2  RA-3     7     A  Aluno-3      2005        17  Menina          2016
# 3  RA-4     7     A  Aluno-4      2005        17  Menino          2017
# 4  RA-5     7     A  Aluno-5      2005        17  Menina          2016
#
#   Instituição de ensino  Pedra 20  ... Inglês Indicado  Atingiu PV    IPV  \
# 0        Escola Pública  Ametista  ...    6.0      Sim         Não  7.278
# 1          Rede Decisão  Ametista  ...    9.7      Não         Não  6.778
# 2          Rede Decisão  Ametista  ...    6.9      Não         Não  7.556
# 3          Rede Decisão  Ametista  ...    8.7      Não         Não  5.278
# 4          Rede Decisão  Ametista  ...    5.7      Não         Não  7.389
#
#     IAN               Fase ideal  Defas  \
# 0   5.0  Fase 8 (Universitários)     -1
# 1  10.0           Fase 7 (3º EM)      0
# 2  10.0           Fase 7 (3º EM)      0
# 3  10.0           Fase 7 (3º EM)      0
# 4  10.0           Fase 7 (3º EM)      0
#
#                                         Destaque IEG  \
# 0  Melhorar: Melhorar a sua entrega de lições de ...
# 1  Melhorar: Melhorar a sua entrega de lições de ...
# 2    Destaque: A sua boa entrega das lições de casa.
# 3  Melhorar: Melhorar a sua entrega de lições de ...
# 4    Destaque: A sua boa entrega das lições de casa.
#
#                                         Destaque IDA  \
# 0  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 1  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 2  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 3  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 4  Melhorar: Empenhar-se mais nas aulas e avaliaç...
#
#                                         Destaque IPV
# 0  Melhorar: Integrar-se mais aos Princípios Pass...
# 1  Melhorar: Integrar-se mais aos Princípios Pass...
# 2  Destaque: A sua boa integração aos Princípios ...
# 3  Melhorar: Integrar-se mais aos Princípios Pass...
# 4  Melhorar: Integrar-se mais aos Princípios Pass...
#
# [5 rows x 42 columns]

# %%
data.shape
# Out:
# (860, 42)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 860 entries, 0 to 859
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RA                     860 non-null    object
#  1   Fase                   860 non-null    int64
#  2   Turma                  860 non-null    object
#  3   Nome                   860 non-null    object
#  4   Ano nasc               860 non-null    int64
#  5   Idade 22               860 non-null    int64
#  6   Gênero                 860 non-null    object
#  7   Ano ingresso           860 non-null    int64
#  8   Instituição de ensino  860 non-null    object
#  9   Pedra 20               323 non-null    object
#  10  Pedra 21               462 non-null    object
#  11  Pedra 22               860 non-null    object
#  12  INDE 22                860 non-null    float64
#  13  Cg                     860 non-null    int64
#  14  Cf                     860 non-null    int64
#  15  Ct                     860 non-null    int64
#  16  Nº Av                  860 non-null    int64
#  17  Avaliador1             860 non-null    object
#  18  Rec Av1                860 non-null    object
#  19  Avaliador2             860 non-null    object
#  20  Rec Av2                860 non-null    object
#  21  Avaliador3             534 non-null    object
#  22  Rec Av3                860 non-null    object
#  23  Avaliador4             310 non-null    object
#  24  Rec Av4                296 non-null    object
#  25  IAA                    860 non-null    float64
#  26  IEG                    860 non-null    float64
#  27  IPS                    860 non-null    float64
#  28  Rec Psicologia         860 non-null    object
#  29  IDA                    860 non-null    float64
#  30  Matem                  858 non-null    float64
#  31  Portug                 858 non-null    float64
#  32  Inglês                 283 non-null    float64
#  33  Indicado               860 non-null    object
#  34  Atingiu PV             860 non-null    object
#  35  IPV                    860 non-null    float64
#  36  IAN                    860 non-null    float64
#  37  Fase ideal             860 non-null    object
#  38  Defas                  860 non-null    int64
#  39  Destaque IEG           860 non-null    object
#  40  Destaque IDA           860 non-null    object
#  41  Destaque IPV           860 non-null    object
# dtypes: float64(10), int64(9), object(23)
# memory usage: 282.3+ KB

# %%
rename_columns = {
    "Ano nasc": "Ano de Nascimento do Aluno",
    "Idade 22": "Idade do Aluno",
    "Ano ingresso": "Ano de Ingresso na Passos Mágicos",
    "INDE 22": "Índice de Desenvolvimento Educacional (INDE)",
    "Cg": "Classificação Geral (Ranking Geral)",
    "Cf": "Classificação na Fase (Ranking por Fase)",
    "Ct": "Classificação na Turma (Ranking por Turma)",
    "Pedra 20": "Pedra 2020",
    "Pedra 21": "Pedra 2021",
    "Pedra 22": "Pedra 2022",
    "Nº Av": "Quantidade de Avaliações",
    "Avaliador1": "Equipe Avaliadora 1",
    "Rec Av1": "Recomendação da Equipe Avaliadora 1",
    "Avaliador2": "Equipe Avaliadora 2",
    "Rec Av2": "Recomendação da Equipe Avaliadora 2",
    "Avaliador3": "Equipe Avaliadora 3",
    "Rec Av3": "Recomendação da Equipe Avaliadora 3",
    "Avaliador4": "Equipe Avaliadora 4",
    "Rec Av4": "Recomendação da Equipe Avaliadora 4",
    "IAA": "Indicador de Autoavaliação",
    "IEG": "Indicador de Engajamento",
    "IPS": "Indicador Psicossocial",
    "Rec Psicologia": "Recomendação da Equipe de Psicologia",
    "IDA": "Indicador de Aprendizagem",
    "Matem": "Nota Média de Matemática",
    "Portug": "Nota Média de Português",
    "Inglês": "Nota Média de Inglês",
    "Indicado": "Indicado para Bolsa",
    "Atingiu PV": "Atingiu Ponto de Virada",
    "IPV": "Indicador de Ponto de Virada",
    "IAN": "Indicador de Adequação ao Nível",
    "Defas": "Nível de Defasagem",
    "Destaque IEG": "Observações sobre Indicador de Engajamento",
    "Destaque IDA": "Observações sobre Indicador de Aprendizagem",
    "Destaque IPV": "Observações sobre Indicador de Ponto de Virada"
}

# %%
pd.set_option('display.max_columns', None)
df = data.rename(columns=rename_columns)
df.head()
# Out:
#      RA  Fase Turma     Nome  Ano de Nascimento do Aluno  Idade do Aluno  \
# 0  RA-1     7     A  Aluno-1                        2003              19
# 1  RA-2     7     A  Aluno-2                        2005              17
# 2  RA-3     7     A  Aluno-3                        2005              17
# 3  RA-4     7     A  Aluno-4                        2005              17
# 4  RA-5     7     A  Aluno-5                        2005              17
#
#    Gênero  Ano de Ingresso na Passos Mágicos Instituição de ensino Pedra 2020  \
# 0  Menina                               2016        Escola Pública   Ametista
# 1  Menina                               2017          Rede Decisão   Ametista
# 2  Menina                               2016          Rede Decisão   Ametista
# 3  Menino                               2017          Rede Decisão   Ametista
# 4  Menina                               2016          Rede Decisão   Ametista
#
#   Pedra 2021 Pedra 2022  Índice de Desenvolvimento Educacional (INDE)  \
# 0   Ametista    Quartzo                                         5.783
# 1   Ametista   Ametista                                         7.055
# 2   Ametista      Ágata                                         6.591
# 3   Ametista    Quartzo                                         5.951
# 4   Ametista   Ametista                                         7.427
#
#    Classificação Geral (Ranking Geral)  \
# 0                                  753
# 1                                  469
# 2                                  629
# 3                                  731
# 4                                  344
#
#    Classificação na Fase (Ranking por Fase)  \
# 0                                        18
# 1                                         8
# 2                                        13
# 3                                        15
# 4                                         6
#
#    Classificação na Turma (Ranking por Turma)  Quantidade de Avaliações  \
# 0                                          10                         4
# 1                                           3                         4
# 2                                           6                         4
# 3                                           7                         4
# 4                                           2                         4
#
#   Equipe Avaliadora 1 Recomendação da Equipe Avaliadora 1 Equipe Avaliadora 2  \
# 0         Avaliador-5               Mantido na Fase atual        Avaliador-27
# 1         Avaliador-5                   Promovido de Fase        Avaliador-27
# 2         Avaliador-5                   Promovido de Fase        Avaliador-27
# 3         Avaliador-5                   Promovido de Fase        Avaliador-27
# 4         Avaliador-5                   Promovido de Fase        Avaliador-27
#
#   Recomendação da Equipe Avaliadora 2 Equipe Avaliadora 3  \
# 0           Promovido de Fase + Bolsa        Avaliador-28
# 1           Promovido de Fase + Bolsa        Avaliador-28
# 2           Promovido de Fase + Bolsa        Avaliador-28
# 3               Mantido na Fase atual        Avaliador-28
# 4           Promovido de Fase + Bolsa        Avaliador-28
#
#   Recomendação da Equipe Avaliadora 3 Equipe Avaliadora 4  \
# 0                   Promovido de Fase        Avaliador-31
# 1                   Promovido de Fase        Avaliador-31
# 2           Promovido de Fase + Bolsa        Avaliador-31
# 3               Mantido na Fase atual        Avaliador-31
# 4           Promovido de Fase + Bolsa        Avaliador-31
#
#   Recomendação da Equipe Avaliadora 4  Indicador de Autoavaliação  \
# 0               Mantido na Fase atual                         8.3
# 1           Promovido de Fase + Bolsa                         8.8
# 2           Promovido de Fase + Bolsa                         0.0
# 3               Mantido na Fase atual                         8.8
# 4           Promovido de Fase + Bolsa                         7.9
#
#    Indicador de Engajamento  Indicador Psicossocial  \
# 0                       4.1                     5.6
# 1                       5.2                     6.3
# 2                       7.9                     5.6
# 3                       4.5                     5.6
# 4                       8.6                     5.6
#
#   Recomendação da Equipe de Psicologia  Indicador de Aprendizagem  \
# 0                     Requer avaliação                        4.0
# 1                       Sem limitações                        6.8
# 2                       Sem limitações                        5.6
# 3                     Requer avaliação                        5.0
# 4                     Requer avaliação                        5.2
#
#    Nota Média de Matemática  Nota Média de Português  Nota Média de Inglês  \
# 0                       2.7                      3.5                   6.0
# 1                       6.3                      4.5                   9.7
# 2                       5.8                      4.0                   6.9
# 3                       2.8                      3.5                   8.7
# 4                       7.0                      2.9                   5.7
#
#   Indicado para Bolsa Atingiu Ponto de Virada  Indicador de Ponto de Virada  \
# 0                 Sim                     Não                         7.278
# 1                 Não                     Não                         6.778
# 2                 Não                     Não                         7.556
# 3                 Não                     Não                         5.278
# 4                 Não                     Não                         7.389
#
#    Indicador de Adequação ao Nível               Fase ideal  \
# 0                              5.0  Fase 8 (Universitários)
# 1                             10.0           Fase 7 (3º EM)
# 2                             10.0           Fase 7 (3º EM)
# 3                             10.0           Fase 7 (3º EM)
# 4                             10.0           Fase 7 (3º EM)
#
#    Nível de Defasagem         Observações sobre Indicador de Engajamento  \
# 0                  -1  Melhorar: Melhorar a sua entrega de lições de ...
# 1                   0  Melhorar: Melhorar a sua entrega de lições de ...
# 2                   0    Destaque: A sua boa entrega das lições de casa.
# 3                   0  Melhorar: Melhorar a sua entrega de lições de ...
# 4                   0    Destaque: A sua boa entrega das lições de casa.
#
#          Observações sobre Indicador de Aprendizagem  \
# 0  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 1  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 2  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 3  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 4  Melhorar: Empenhar-se mais nas aulas e avaliaç...
#
#       Observações sobre Indicador de Ponto de Virada
# 0  Melhorar: Integrar-se mais aos Princípios Pass...
# 1  Melhorar: Integrar-se mais aos Princípios Pass...
# 2  Destaque: A sua boa integração aos Princípios ...
# 3  Melhorar: Integrar-se mais aos Princípios Pass...
# 4  Melhorar: Integrar-se mais aos Princípios Pass...

# %%
df.drop(columns=["Nome"],inplace=True)

# %%
df.to_csv("base_dados_pede_2024_ajustado.csv", index=False)
